# %%
test = ['(', '광고', ')', 'XXXBaXXX', '고객', '님', '들다', '뒤', '엔', 'XXX', '언제나', 'XXX', '새롭다', '마음가짐', '으로', '새롭다', '준비', '하다', '.', '당', '행', '상품', '의', '자격', '기준', '과', '심사', '기준', '이', '완화', '되어다', '상품', '에', '대해', '간단하다', '상품', '정보', '전달', '드리다', '.', '수신', '을', '희망', '하다', '않다', '경우', '에는', '거부', '라는', '답장', '을', '주시', '면', 'KISA', '수신', '거부', '목록', '에', '등록', '을', '시키다', '두', '번', '다시', '발송', '되다', '않다', '조치', '를', '취', '해드리다', '.', '신청', '방법', ':', 'XXX', '-', 'XXX', '-', 'XXX', '터치', '하다', '문자', '로', '상담', '또는', '00시', '00분', '상담', '이라고', '답장', '을', '보내다', '전화', '를', '주시', '면', '친절하다', '안전하다', '상담', '으로', '도움', '드리다', '.', '카카오', '톡', '상담', '서비스', '시행', '중', 'citibankloan', '친구', '추가', '후', '상담', '신청', '이렇다', '분', '들', '께', '권', '해드리다', '.', '1', '.', '시중', '은행권', '에서', '기존', '한도', '를', '모두', '사용', '중', '이신', '분', '.', '2', '.', '기', '대출', '의', '원리금', '균등', '방식', '으로', '인하다', '월', '불입', '금액', '이', '부담스럽다', '분', '.', '3', '.', '총', '채무', '금액', '은', '작다', '채', '무겁다', '많다', '관리', '가', '안', '되다', 'XXX', '고객', '님', '들다', '말씀드리다', '.', '높다', '금리', '때문', '에', '힘들다', '느끼다', '때', '대출', '이', '필요하다', '때', '언제나', 'XXX', '고객', '님', '들다', '뒤', '에서', '든든하다', '파트너', '로서', '도', '와', '드리다', '.', '당', '행', '상품', '특징', '1', '.', '당', '행', '거래', '가', '없다', '진행', '가능', '.', '2', '.', '시중', '은행권', '보다', '높다', '한도', '.', '3', '.', '자체', '등급', '으로', '판단', '하므다', '낮다', '신용', '자', '도', '진행', '가능', '.', '4', '.', '부채', '가', '많다', '부채', '통합', '상품', '으로', '전환', '가능', '.', '5', '.', '원리금', '균등', '방식', '을', '이자', '만', '납', '입하', '는', '만기일', '시로', '전환', '가능', '.', '6', '.', '가상', '조회', '를', '통해', '한도', '및', '금리', '를', '하다', '번', '에', '확인가능', '.', '당', '행', '상품', '안내', '1', '.', '직장인', '전용', '신용', '상품', '한도', ':', '최대', '1억', '4000만', '원', '까지', '.', '금리', ':', '최저', '2.97%', '자격', ':', 'XXX', '은행', '자체', '등급', '과', '기업', '리스트', '에', '따르다', '차등', '적용', '.', '2', '.', '채무', '통합', '전환', '상품', '한도', ':', '연봉', '대비', '300%', '까지', '.', '금리', ':', '최저', '2.97%', '자격', ':', 'XXX', '은행', '자체', '등급', '과', '기업', '리스트', '에', '따르다', '차등', '적용', '.', '3', '.', '새', '희망', '홀씨', '한도', ':', '최대', '2500만', '원', '.', '금리', ':', '8.68%', '12%', '자격', ':', '연봉', '4000만', '원', '이하', '고객', '대상', '으로', 'XXX', '자체', '등급', '에', '따르다', '(', '광고', ')', 'XXX']
def del_special_and_x(raw_list_):
    new_list = list()
    for str_ in raw_list_:
        tmp = ""
        for ch in str_:
            if ch.isalpha() and ch != 'X':
                tmp += ch
        if len(tmp) != 0: new_list.append(tmp)
    return new_list
del_special_and_x(test)
# Out:
# ['광고',
#  'Ba',
#  '고객',
#  '님',
#  '들다',
#  '뒤',
#  '엔',
#  '언제나',
#  '새롭다',
#  '마음가짐',
#  '으로',
#  '새롭다',
#  '준비',
#  '하다',
#  '당',
#  '행',
#  '상품',
#  '의',
#  '자격',
#  '기준',
#  '과',
#  '심사',
#  '기준',
#  '이',
#  '완화',
#  '되어다',
#  '상품',
#  '에',
#  '대해',
#  '간단하다',
#  '상품',
#  '정보',
#  '전달',
#  '드리다',
#  '수신',
#  '을',
#  '희망',
#  '하다',
#  '않다',
#  '경우',
#  '에는',
#  '거부',
#  '라는',
#  '답장',
#  '을',
#  '주시',
#  '면',
#  'KISA',
#  '수신',
#  '거부',
#  '목록',
#  '에',
#  '등록',
#  '을',
#  '시키다',
#  '두',
#  '번',
#  '다시',
#  '발송',
#  '되다',
#  '않다',
#  '조치',
#  '를',
#  '취',
#  '해드리다',
#  '신청',
#  '방법',
#  '터치',
#  '하다',
#  '문자',
#  '로',
#  '상담',
#  '또는',
#  '시',
#  '분',
#  '상담',
#  '이라고',
#  '답장',
#  '을',
#  '보내다',
#  '전화',
#  '를',
#  '주시',
#  '면',
#  '친절하다',
#  '안전하다',
#  '상담',
#  '으로',
#  '도움',
#  '드리다',
#  '카카오',
#  '톡',
#  '상담',
#  '서비스',
#  '시행',
#  '중',
#  'citibankloan',
#  '친구',
#  '추가',
#  '후',
#  '상담',
#  '신청',
#  '이렇다',
#  '분',
#  '들',
#  '께',
#  '권',
#  '해드리다',
#  '시중',
#  '은행권',
# ...
