# %%
import pandas as pd
PATH = "C:/Users/SooHwanKim/Desktop/SooHwan/Workspace/python_workspace/Korean-ASR/Korean-ASR/data/train_list.csv"
pd.read_csv(PATH, "r",delimiter=",", encoding="UTF-8")
# Out:
#                        audio                       label
# 0       KaiSpeech_000001.pcm  KaiSpeech_label_000001.txt
# 1       KaiSpeech_000002.pcm  KaiSpeech_label_000002.txt
# 2       KaiSpeech_000003.pcm  KaiSpeech_label_000003.txt
# 3       KaiSpeech_000004.pcm  KaiSpeech_label_000004.txt
# 4       KaiSpeech_000005.pcm  KaiSpeech_label_000005.txt
# 5       KaiSpeech_000006.pcm  KaiSpeech_label_000006.txt
# 6       KaiSpeech_000007.pcm  KaiSpeech_label_000007.txt
# 7       KaiSpeech_000008.pcm  KaiSpeech_label_000008.txt
# 8       KaiSpeech_000009.pcm  KaiSpeech_label_000009.txt
# 9       KaiSpeech_000010.pcm  KaiSpeech_label_000010.txt
# 10      KaiSpeech_000011.pcm  KaiSpeech_label_000011.txt
# 11      KaiSpeech_000012.pcm  KaiSpeech_label_000012.txt
# 12      KaiSpeech_000013.pcm  KaiSpeech_label_000013.txt
# 13      KaiSpeech_000014.pcm  KaiSpeech_label_000014.txt
# 14      KaiSpeech_000015.pcm  KaiSpeech_label_000015.txt
# ...

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
path = "E:/한국어 음성데이터/KaiSpeech/KaiSpeech_101025.pcm"
audio = np.memmap(path)
print(audio)
# Out:
# [ 6  0  8 ...  0 49  0]
