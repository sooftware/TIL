# %%
with open('datalist') as f:
# Out:
#   File "<ipython-input-2-fa0ab6e93204>", line 1
#     with open('datalist') as f:
#                                ^
# SyntaxError: unexpected EOF while parsing
